# %%
depthArray = []
with open('./day1.txt') as my_file:
    for line in my_file:
        depthArray.append(int(line.strip()))
depthArray
# Out:
# [199,
#  203,
#  200,
#  201,
#  196,
#  195,
#  196,
#  214,
#  227,
#  225,
#  229,
#  260,
#  246,
#  253,
#  271,
#  281,
#  280,
#  295,
#  310,
#  293,
#  295,
#  297,
#  298,
#  297,
#  306,
#  299,
#  290,
#  292,
#  289,
#  287,
#  291,
#  296,
#  294,
#  287,
#  286,
#  287,
#  289,
#  290,
#  281,
#  283,
#  282,
#  275,
#  256,
#  265,
#  242,
#  231,
#  226,
#  216,
#  227,
#  226,
#  249,
#  238,
#  237,
#  247,
#  245,
#  250,
#  264,
#  267,
#  259,
#  258,
#  264,
#  261,
#  249,
#  246,
#  239,
#  240,
#  259,
#  258,
#  280,
#  279,
#  278,
#  281,
#  272,
#  256,
#  255,
#  271,
#  286,
#  290,
#  286,
#  288,
#  290,
#  294,
#  292,
#  294,
#  292,
#  293,
#  294,
#  291,
#  298,
#  303,
#  301,
#  330,
#  331,
#  336,
#  362,
#  371,
#  374,
#  368,
#  367,
#  368,
#  366,
#  364,
#  371,
#  377,
#  378,
#  384,
#  386,
#  388,
#  393,
#  409,
#  423,
#  422,
#  411,
#  412,
#  426,
#  430,
#  441,
#  460,
#  462,
#  464,
#  469,
#  461,
#  483,
#  452,
#  455,
# ...

# %%
testArray = [199,
             200,
             208,
             210,
             200,
             207,
             240,
             269,
             260,
             263]
count = 0
prevValue = 1000000
for value in testArray:
    if value > prevValue:
        count += 1
    prevValue = value
   
print(count)
#count("increasing") in testArray
# Out:
# 7
